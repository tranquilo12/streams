# %% [markdown]
# ### Goals

# %% [markdown]
# - What are the tickers available in PolygonIO?
# - What's the correlation between two industris? Where does the 'rotation' take place?

# %% [markdown]
# ### Imports

# %%
import sys
import os
import requests

# sys.path.append("C:\\Users\\SHIRAM\\Documents\\streams")
sys.path.append("/mnt/c/Users/SHIRAM/Documents/streams/")

from connections import Connections
from multi_thread_streams import get_distinct_col_values_from_equities_info, get_multiple_distinct_col_values_from_equities_info
from multi_thread_streams import establish_ssh_tunnel

import pandas as pd
import numpy as np 
from functools import reduce

from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL

from math import pi
import psycopg2

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [markdown]
# ### Functions

# %%
if "read_db" in locals():
    del read_db
    
def read_db(
    table_name:str=None, 
    columns:list=None, 
    condition:str=None, 
    ssh_conn_params:dict=None, 
    db_conn_params:dict=None, 
    query:str=None,
    use_sqlalchemy:bool=True
):
    """
    All query's will be run from tunnel init here, as freq of query's will be low.
    """
    
    # a bit more flexibility on column level
    if query is None:
        if columns[0] != "*":
            columns = ', '.join(columns)
        else:
            columns = columns[0]
        query = f"SELECT {columns} FROM {table_name} WHERE {condition};"
    
    # tunnel and all others are 
    tunnel = establish_ssh_tunnel(ssh_conn_params=ssh_conn_params)
    tunnel.daemon_transport = True
    tunnel.daemon_forward_servers = True
    # tunnel.start()
    
    # local bind port will be used by both psycopg2 and sqlalchemy conditions
    db_conn_params["port"] = 5433 # int(tunnel.local_bind_port)
    
    if use_sqlalchemy:
        # need to change the 'user' key to 'username', if the key is found
        if "user" in db_conn_params.keys():
            username = db_conn_params.pop("user")
            db_conn_params["username"] = username
        
        # some other conditons that are not accepted by the engine are thrown out
        for ele in ["keepalives", "keepalives_idle", "keepalives_interval", "keepalives_count"]:
            if ele in db_conn_params.keys():
                _ = db_conn_params.pop(ele)
        
        db_conn_params["drivername"] = "postgresql+psycopg2"
        engine = create_engine(URL(**db_conn_params))
        result = pd.read_sql_query(sql=query, con=engine)
        
    else:
        with psycopg2.connect(**db_conn_params) as conn:
            with conn.cursor() as cur:
                cur.execute(query)
                result = cur.fetchall()
            
#     if tunnel.is_alive | tunnel.is_active:
#         tunnel.stop()
        
    return result

if "get_data" in locals():
    del get_data
    
def get_data(industries:list = None, sectors:list = None) -> pd.DataFrame:
    """
    Filter by multiple industries and sectors
    """
    query = ["SELECT A.*, B.industry, B.sector FROM polygon_stocks_agg_candles A LEFT JOIN equities_info B ON B.symbol = A.ticker"]
    
    if industries is not None:
        industries = [f"'{val}'" for val in industries]
        industries = ", ".join(industries)
        query += [f"WHERE B.industry in ({industries})"]
        
    if sectors is not None:
        sectors = [f"'{val}'" for val in sectors]
        sectors = ", ".join(sectors)
        if len(query) > 1:
            query += [f"AND B.sector in ({sectors}) AND A.timespan = 'day'"]
        else:
            query += [f"WHERE B.sector in ({sectors}) AND A.timespan = 'day'"]
    
    query = " ".join(query)
    query = f"{query};"
    res = read_db(
        query = query,
        ssh_conn_params=conns.ssh_conn_params, 
        db_conn_params=conns.db_conn_params, 
        use_sqlalchemy=True
    )
    return res

if "process_data" in locals():
    del process_data
    
def process_data(df:pd.DataFrame, close:bool=True, ohlc:bool=False) -> pd.DataFrame:
    if close:
        cols = ["timestamp", "ticker", "close", "vwap", "industry", "sector"]
        
    if ohlc:
        cols = ["timestamp", "ticker", "open", "high", "low", "close", "vwap", "industry", "sector"]
        
    df = df[cols]
    
    cols = list(df.columns)
    cols[0] = "date"
    df.columns = cols
    
    df.loc[:, "date"] = pd.to_datetime(df["date"])
    df = df.sort_values(by="date")
    
    return df

# %% [markdown]
# ### Calls

# %%
# to fetch data from cloud
conns = Connections()

results = get_multiple_distinct_col_values_from_equities_info(
    logger=conns.logger, 
    ssh_conn_params=conns.ssh_conn_params, 
    db_conn_params=conns.db_conn_params, 
    col_names=["industry", "sector"]
)

energy_df = process_data(df=get_data(sectors=["Energy"]), close=True)
finance_df = process_data(df=get_data(sectors=["Finance"]), close=True)

# energy_df.to_csv("energy_tickers.csv", index=True)
# finance_df.to_csv("finance_tickers.csv", index=True)
# Out:
# 2020-11-14 03:31:07 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:07 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:07 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:07 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:08 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:416}-INFO-Making ssh tunnel to get sectors list...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:427}-INFO-Querying db...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...
# 2020-11-14 03:31:09 PM-{/mnt/c/Users/SHIRAM/Documents/streams/multi_thread_streams.py:429}-INFO-Fetchall query...

# %%
from tqdm.notebook import tqdm_notebook

# %%
conns.establish_rest_client()
client = conns.rest_client
tickers = []
for page in tqdm_notebook(range(1, 10000)):
    try:
        tkr = client.reference_tickers(page=page)
        tickers.append(tkr)
    except Exception as e: 
        print(f"Exception: {e}")
# Out:
# 2020-11-14 03:58:00 PM-{/mnt/c/Users/SHIRAM/Documents/streams/connections.py:241}-INFO-Polygon REST connection established
# 2020-11-14 03:58:00 PM-{/mnt/c/Users/SHIRAM/Documents/streams/connections.py:241}-INFO-Polygon REST connection established
# 2020-11-14 03:58:00 PM-{/mnt/c/Users/SHIRAM/Documents/streams/connections.py:241}-INFO-Polygon REST connection established
# 2020-11-14 03:58:00 PM-{/mnt/c/Users/SHIRAM/Documents/streams/connections.py:241}-INFO-Polygon REST connection established
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=9999.0), HTML(value='')))
# Exception: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-f95c61b61611> in <module>
#       4 for page in tqdm_notebook(range(1, 10000)):
#       5     try:
# ----> 6         tkr = client.reference_tickers(page=page)
#       7         tickers.append(tkr)
#       8     except Exception as e:
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/polygon/rest/client.py in reference_tickers(self, **query_params)
#      37     def reference_tickers(self, **query_params) -> models.ReferenceTickersApiResponse:
#      38         endpoint = f"{self.url}/v2/reference/tickers"
# ---> 39         return self._handle_response("ReferenceTickersApiResponse", endpoint, query_params)
#      40
#      41     def reference_ticker_types(self, **query_params) -> models.ReferenceTickerTypesApiResponse:
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/polygon/rest/client.py in _handle_response(self, response_type, endpoint, params)
#      29
#      30     def _handle_response(self, response_type: str, endpoint: str, params: Dict[str, str]) -> Type[models.AnyDefinition]:
# ---> 31         resp: requests.Response = self._session.get(endpoint, params=params, timeout=self.timeout)
#      32         if resp.status_code == 200:
#      33             return unmarshal.unmarshal_json(response_type, resp.json())
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /mnt/c/Users/SHIRAM/AppData/Local/pypoetry/Cache/virtualenvs/streams-wbHx_Xqh-py3.6/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
all_tickers = []
for tkr in tqdm_notebook(tickers):
    all_tickers += tkr.tickers
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4026.0), HTML(value='')))

# %%
all_tickers_df = pd.DataFrame.from_dict(all_tickers)

# %%
all_tickers_df[all_tickers_df["market"] == "INDICES"]
# Out:
#         ticker                                               name   market  \
# 17982   I:AAXJ  iShares MSCI All Country Asia ex Japan Index Fund  INDICES
# 17983   I:ABAQ                          ABA NASDAQ Community Bank  INDICES
# 17984   I:ABQI                      NASDAQ OMX ABA Community Bank  INDICES
# 17985   I:ABQX            NASDAQ OMX ABA Community Bank Total Rtn  INDICES
# 17986   I:ACWI                       iShares MSCI ACWI Index Fund  INDICES
# ...        ...                                                ...      ...
# 100681  I:ZPRS                SPDR MSCI World Small Cap UCITS ETF  INDICES
# 100682  I:ZPRU             SPDR MSCI USA Value Weighted UCITS ETF  INDICES
# 100683  I:ZPRV   SPDR MSCI USA Small Cap Value Weighted UCITS ETF  INDICES
# 100684  I:ZPRW          SPDR MSCI Europe Value Weighted UCITS ETF  INDICES
# 100685  I:ZPRX  SPDR MSCI Europe Small Cap Value Weighted UCIT...  INDICES
#
#        locale   type currency  active primaryExch     updated codes  \
# 17982       G    ETF      USD    True        GIDS  2020-11-14   NaN
# 17983       G  INDEX      USD    True        GIDS  2020-11-14   NaN
# 17984       G  INDEX      USD    True        GIDS  2020-11-14   NaN
# 17985       G  INDEX      USD    True        GIDS  2020-11-14   NaN
# 17986       G    ETF      USD    True        GIDS  2020-11-14   NaN
# ...       ...    ...      ...     ...         ...         ...   ...
# 100681      G    ETF      USD    True        GIDS  2020-01-30   NaN
# 100682      G    ETF      USD    True        GIDS  2020-01-30   NaN
# 100683      G    ETF      USD    True        GIDS  2020-01-30   NaN
# 100684      G    ETF      USD    True        GIDS  2020-01-30   NaN
# 100685      G    ETF      USD    True        GIDS  2020-01-30   NaN
#
#                                              url  \
# 17982   https://api.polygon.io/v2/tickers/I:AAXJ
# 17983   https://api.polygon.io/v2/tickers/I:ABAQ
# 17984   https://api.polygon.io/v2/tickers/I:ABQI
# 17985   https://api.polygon.io/v2/tickers/I:ABQX
# 17986   https://api.polygon.io/v2/tickers/I:ACWI
# ...                                          ...
# 100681  https://api.polygon.io/v2/tickers/I:ZPRS
# 100682  https://api.polygon.io/v2/tickers/I:ZPRU
# 100683  https://api.polygon.io/v2/tickers/I:ZPRV
# 100684  https://api.polygon.io/v2/tickers/I:ZPRW
# 100685  https://api.polygon.io/v2/tickers/I:ZPRX
#
#                                                     attrs
# 17982                                                  {}
# 17983   {'holiday': False, 'assettype': 'EQ', 'entitle...
# 17984   {'holiday': False, 'assettype': 'EQ', 'entitle...
# 17985   {'holiday': False, 'assettype': 'EQ', 'entitle...
# 17986                                                  {}
# ...                                                   ...
# 100681                                                 {}
# 100682                                                 {}
# 100683                                                 {}
# 100684                                                 {}
# 100685                                                 {}
#
# [82704 rows x 12 columns]

# %%
class Worker(Thread):
    """Thread executing tasks from a given tasks queue"""

    def __init__(self, tasks):
        Thread.__init__(self)
        self.tasks = tasks
        self.daemon = True
        self.start()

    def run(self):
        while True:
            func, args, kwargs = self.tasks.get()
            try:
                func(*args, **kwargs)
            except Exception as e:
                print(f"Exception: {e}")

            self.tasks.task_done()


class ThreadPool:
    """Pool of threads consuming tasks from a queue"""

    def __init__(self, num_threads):
        self.tasks = Queue(num_threads)
        for _ in range(num_threads):
            Worker(self.tasks)

    def add_tasks(self, func, *args, **kwargs):
        self.tasks.put((func, args, kwargs))

    def wait_completion(self):
        self.tasks.join()

# %%
pool = ThreadPool(num_threads=100)
for eq in tqdm()

# %%
tickers.tickers
# Out:
# [{'ticker': 'AAMC',
#   'name': 'Altisource Asset Mgmt Corp',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'AMX',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001555074',
#    'figiuid': 'EQ0000000027544942',
#    'scfigi': 'BBG003PNL145',
#    'cfigi': 'BBG003PNL136',
#    'figi': 'BBG003Q1GJL0'},
#   'url': 'https://api.polygon.io/v2/tickers/AAMC'},
#  {'ticker': 'AAME',
#   'name': 'Atlantic American Corporation Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000008177',
#    'figiuid': 'EQ0010179600001000',
#    'scfigi': 'BBG001S5N8T1',
#    'cfigi': 'BBG000B9XB24',
#    'figi': 'BBG000B9XMQ4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAME'},
#  {'ticker': 'AAMMF',
#   'name': 'Almadex Minerals Ltd Ordinary Shares (Canada)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000065322418',
#    'scfigi': 'BBG00K66WBV1',
#    'cfigi': 'BBG00L1LR0B3',
#    'figi': 'BBG00L1LR0T4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAMMF'},
#  {'ticker': 'AAMTF',
#   'name': 'Armada Mercantile Ltd Ordinary Shares',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000000079249',
#    'scfigi': 'BBG001S6TJ73',
#    'cfigi': 'BBG000K7V8F3',
#    'figi': 'BBG000K7WLN4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAMTF'},
#  {'ticker': 'AAN',
#   'name': "Aaron''s Holdings Company, Inc.",
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NYE',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000706688',
#    'figiuid': 'EQ0010218800003000',
#    'scfigi': 'BBG001S7STN2',
#    'cfigi': 'BBG000D9V7T4',
#    'figi': 'BBG000D9VBX0'},
#   'url': 'https://api.polygon.io/v2/tickers/AAN'},
#  {'ticker': 'AANC',
#   'name': 'Andover National Corp',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'GREY',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000072131195',
#    'scfigi': 'BBG00NBFLVW6',
#    'cfigi': 'BBG00NBFLV47',
#    'figi': 'BBG00NBFLVL8'},
#   'url': 'https://api.polygon.io/v2/tickers/AANC'},
#  {'ticker': 'AANNF',
#   'name': 'Aroundtown SA Ordinary Shares (Luxembourg)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000064692116',
#    'scfigi': 'BBG007PSVBP9',
#    'cfigi': 'BBG00KT2BP01',
#    'figi': 'BBG00KT2BPF5'},
#   'url': 'https://api.polygon.io/v2/tickers/AANNF'},
#  {'ticker': 'AANOF',
#   'name': 'Asciano Limited',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'GREY',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001469014',
#    'figiuid': 'EQ0000000003832407',
#    'scfigi': 'BBG001SQT515',
#    'cfigi': 'BBG000RVXDQ8',
#    'figi': 'BBG000RVXDQ8'},
#   'url': 'https://api.polygon.io/v2/tickers/AANOF'},
#  {'ticker': 'AANR',
#   'name': 'ANR Inc',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTO',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000062945412',
#    'scfigi': 'BBG00K2SNRQ8',
#    'cfigi': 'BBG00K2SNRP9',
#    'figi': 'BBG00K2SNRP9'},
#   'url': 'https://api.polygon.io/v2/tickers/AANR'},
#  {'ticker': 'AAOI',
#   'name': 'Applied Optoelectronics, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001158114',
#    'figiuid': 'EQ0000000001293648',
#    'scfigi': 'BBG001SG47G4',
#    'cfigi': 'BBG000D6VW15',
#    'figi': 'BBG00564XR16'},
#   'url': 'https://api.polygon.io/v2/tickers/AAOI'},
#  {'ticker': 'AAOMF',
#   'name': 'Atlas Consolidated Mining & Development Corporation',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTO',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000028567381',
#    'scfigi': 'BBG001S6NXX9',
#    'cfigi': 'BBG00443PWH4',
#    'figi': 'BBG00443PWH4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAOMF'},
#  {'ticker': 'AAON',
#   'name': 'AAON, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000824142',
#    'figiuid': 'EQ0010179800001000',
#    'scfigi': 'BBG001S6CZK0',
#    'cfigi': 'BBG000C2LZP3',
#    'figi': 'BBG000C2M952'},
#   'url': 'https://api.polygon.io/v2/tickers/AAON'},
#  {'ticker': 'AAP',
#   'name': 'ADVANCE AUTO PARTS INC',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NYE',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001158449',
#    'figiuid': 'EQ0036823400001000',
#    'scfigi': 'BBG001SD2SB2',
#    'cfigi': 'BBG000F7RCJ1',
#    'figi': 'BBG000F7RFH6'},
#   'url': 'https://api.polygon.io/v2/tickers/AAP'},
#  {'ticker': 'AAPCF',
#   'name': 'Atlantic Alliance Partnership Corp',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': False,
#   'primaryExch': 'OTO',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001630940',
#    'figiuid': 'EQ0000000041289925',
#    'scfigi': 'BBG008651TG2',
#    'cfigi': 'BBG008651TF3',
#    'figi': 'BBG008651VD0'},
#   'url': 'https://api.polygon.io/v2/tickers/AAPCF'},
#  {'ticker': 'AAPH',
#   'name': 'American Petro Hunter Inc',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'CVEM',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001040482',
#    'figiuid': 'EQ0031313900001000',
#    'scfigi': 'BBG001SFQ7T8',
#    'cfigi': 'BBG000F2FL69',
#    'figi': 'BBG000F2FL69'},
#   'url': 'https://api.polygon.io/v2/tickers/AAPH'},
#  {'ticker': 'AAPJ',
#   'name': 'AAP, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0017199300001000',
#    'scfigi': 'BBG001S6BY24',
#    'cfigi': 'BBG000BHS5L4',
#    'figi': 'BBG000BHSCT1'},
#   'url': 'https://api.polygon.io/v2/tickers/AAPJ'},
#  {'ticker': 'AAPL',
#   'name': 'Apple Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000320193',
#    'figiuid': 'EQ0010169500001000',
#    'scfigi': 'BBG001S5N8V8',
#    'cfigi': 'BBG000B9XRY4',
#    'figi': 'BBG000B9Y5X2'},
#   'url': 'https://api.polygon.io/v2/tickers/AAPL'},
#  {'ticker': 'AAPT',
#   'name': 'All American Pet Company, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001362502',
#    'figiuid': 'EQ0000000003472105',
#    'scfigi': 'BBG001SM7HC0',
#    'cfigi': 'BBG000R7ZH35',
#    'figi': 'BBG000R7ZPJ0'},
#   'url': 'https://api.polygon.io/v2/tickers/AAPT'},
#  {'ticker': 'AASCF',
#   'name': 'ALL ACTIVE ASSET CAP LTD Ordinary Shares',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-08-28',
#   'url': 'https://api.polygon.io/v2/tickers/AASCF'},
#  {'ticker': 'AASL',
#   'name': "America's Suppliers, Inc. Common Stock",
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001002390',
#    'figiuid': 'EQ0017324000009000',
#    'scfigi': 'BBG001SBFJH6',
#    'cfigi': 'BBG000JMM577',
#    'figi': 'BBG000JMM577'},
#   'url': 'https://api.polygon.io/v2/tickers/AASL'},
#  {'ticker': 'AASP',
#   'name': 'All-American SportPark, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000930245',
#    'figiuid': 'EQ0015913300001000',
#    'scfigi': 'BBG001S7JJF3',
#    'cfigi': 'BBG000K2W621',
#    'figi': 'BBG000K2YPJ9'},
#   'url': 'https://api.polygon.io/v2/tickers/AASP'},
#  {'ticker': 'AAST',
#   'name': 'Allied American Steel Corp',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'CVEM',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001404212',
#    'figiuid': 'EQ0000000007397568',
#    'scfigi': 'BBG001SV9FK3',
#    'cfigi': 'BBG000C45JQ2',
#    'figi': 'BBG000C45JQ2'},
#   'url': 'https://api.polygon.io/v2/tickers/AAST'},
#  {'ticker': 'AASZF',
#   'name': 'Atlantic Sapphire AS Common Shares',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000064628950',
#    'scfigi': 'BBG00H49DHH8',
#    'cfigi': 'BBG00KRWFZB9',
#    'figi': 'BBG00KRWFZR2'},
#   'url': 'https://api.polygon.io/v2/tickers/AASZF'},
#  {'ticker': 'AAT',
#   'name': 'AMERICAN ASSETS TRUST, INC.',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NYE',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001500217',
#    'figiuid': 'EQ0000000011243999',
#    'scfigi': 'BBG001TCBJS5',
#    'cfigi': 'BBG00161BCR0',
#    'figi': 'BBG00161BCW4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAT'},
#  {'ticker': 'AATAF',
#   'name': 'Arata Corporation',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'JPY',
#   'active': True,
#   'primaryExch': 'GREY',
#   'updated': '2020-06-23',
#   'url': 'https://api.polygon.io/v2/tickers/AATAF'},
#  {'ticker': 'AATDF',
#   'name': 'AA LTD Ordinary Shares (United Kingdom)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000046469184',
#    'scfigi': 'BBG001ST1GJ6',
#    'cfigi': 'BBG00BJTT857',
#    'figi': 'BBG00BJTT8M8'},
#   'url': 'https://api.polygon.io/v2/tickers/AATDF'},
#  {'ticker': 'AATGF',
#   'name': 'ATI Airtest Technologies Inc Ordinary Shares',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0088367600001001',
#    'scfigi': 'BBG001S77XD7',
#    'cfigi': 'BBG000DPPB70',
#    'figi': 'BBG000DPPKS7'},
#   'url': 'https://api.polygon.io/v2/tickers/AATGF'},
#  {'ticker': 'AATP',
#   'name': 'Agape ATP Corporation Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000058883718',
#    'scfigi': 'BBG00HKYNJV4',
#    'cfigi': 'BBG00HKYNJT7',
#    'figi': 'BBG00HKYNJT7'},
#   'url': 'https://api.polygon.io/v2/tickers/AATP'},
#  {'ticker': 'AATRL',
#   'name': 'AMG Capital  Trust II 5.15% Convertible Trust Preferred Securities, Expiring 10/15/2037',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'url': 'https://api.polygon.io/v2/tickers/AATRL'},
#  {'ticker': 'AATV',
#   'name': 'Adaptive Ad Systems, Inc. NEW Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001131251',
#    'figiuid': 'EQ0000000000055581',
#    'scfigi': 'BBG001SGH8Q7',
#    'cfigi': 'BBG000DQDZ96',
#    'figi': 'BBG000DQF616'},
#   'url': 'https://api.polygon.io/v2/tickers/AATV'},
#  {'ticker': 'AAU',
#   'name': 'Almaden Minerals Ltd.',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'AMX',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001015647',
#    'figiuid': 'EQ0000000000083289',
#    'scfigi': 'BBG001S7VVD4',
#    'cfigi': 'BBG000DGFSY4',
#    'figi': 'BBG000DGFTB7'},
#   'url': 'https://api.polygon.io/v2/tickers/AAU'},
#  {'ticker': 'AAUJF',
#   'name': 'AndeanGold Ltd',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'GREY',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000003786762',
#    'scfigi': 'BBG001S6H040',
#    'cfigi': 'BBG000RSJ196',
#    'figi': 'BBG000RSJ196'},
#   'url': 'https://api.polygon.io/v2/tickers/AAUJF'},
#  {'ticker': 'AAUKF',
#   'name': 'Anglo American plc Ordinary Shares (United Kingdom)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000000080598',
#    'scfigi': 'BBG001S5Z1X8',
#    'cfigi': 'BBG000C7T8Q3',
#    'figi': 'BBG000C7VLB7'},
#   'url': 'https://api.polygon.io/v2/tickers/AAUKF'},
#  {'ticker': 'AAUKY',
#   'name': 'Anglo American plc',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTO',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0083398300009000',
#    'scfigi': 'BBG001SCW914',
#    'cfigi': 'BBG000BXTN75',
#    'figi': 'BBG000BXTN75'},
#   'url': 'https://api.polygon.io/v2/tickers/AAUKY'},
#  {'ticker': 'AAVMY',
#   'name': 'Abn Amro BK N V Amsterdam Brh American Depositary Receipts - Unsponsored (Netherlands)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000077763163',
#    'scfigi': 'BBG00PXGLG67',
#    'cfigi': 'BBG00PXGLFG8',
#    'figi': 'BBG00PXGLFX9'},
#   'url': 'https://api.polygon.io/v2/tickers/AAVMY'},
#  {'ticker': 'AAVVF',
#   'name': 'Advantage Oil & Gas Ltd Ordinary Shares (Canada)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0011095700001001',
#    'scfigi': 'BBG001SDWVG7',
#    'cfigi': 'BBG000C5QZ62',
#    'figi': 'BBG000C5S9P7'},
#   'url': 'https://api.polygon.io/v2/tickers/AAVVF'},
#  {'ticker': 'AAVXF',
#   'name': 'Abivax SA Ordinary Shares (France)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000051968603',
#    'scfigi': 'BBG009CG7F82',
#    'cfigi': 'BBG00DX9WMJ1',
#    'figi': 'BBG00DX9WMZ3'},
#   'url': 'https://api.polygon.io/v2/tickers/AAVXF'},
#  {'ticker': 'AAWC',
#   'name': 'Alexandria Advantage Warranty Company Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001165758',
#    'figiuid': 'EQ0000000000761151',
#    'scfigi': 'BBG001SBV999',
#    'cfigi': 'BBG000BS8FQ5',
#    'figi': 'BBG000BS8PB9'},
#   'url': 'https://api.polygon.io/v2/tickers/AAWC'},
#  {'ticker': 'AAWW',
#   'name': 'Atlas Air Worldwide Holdings NEW Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001135185',
#    'figiuid': 'EQ0000000001229493',
#    'scfigi': 'BBG001SM7BG9',
#    'cfigi': 'BBG000Q57YP0',
#    'figi': 'BBG000Q58769'},
#   'url': 'https://api.polygon.io/v2/tickers/AAWW'},
#  {'ticker': 'AAXJ',
#   'name': 'iShares MSCI All Country Asia ex Japan ETF',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000006348535',
#    'scfigi': 'BBG001T2V2D8',
#    'cfigi': 'BBG000G6GXC5',
#    'figi': 'BBG000G6JD36'},
#   'url': 'https://api.polygon.io/v2/tickers/AAXJ'},
#  {'ticker': 'AAXN',
#   'name': 'Axon Enterprise, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NASDAQ',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001069183',
#    'figiuid': 'EQ0174781700001000',
#    'scfigi': 'BBG001SB2HG5',
#    'cfigi': 'BBG000BHJWG1',
#    'figi': 'BBG000BHK5Z7'},
#   'url': 'https://api.polygon.io/v2/tickers/AAXN'},
#  {'ticker': 'AAXT',
#   'name': 'Aamaxan Transport Group, Inc. Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0001358940',
#    'figiuid': 'EQ0013631700001000',
#    'scfigi': 'BBG001SFRD87',
#    'cfigi': 'BBG000BSVKZ8',
#    'figi': 'BBG000BSVTN2'},
#   'url': 'https://api.polygon.io/v2/tickers/AAXT'},
#  {'ticker': 'AAYYY',
#   'name': 'Austrailian Agricultural Company Ltd Unsponsored ADR (Austrailia)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000021581663',
#    'scfigi': 'BBG002CND7J1',
#    'cfigi': 'BBG002CND6S3',
#    'figi': 'BBG002CND783'},
#   'url': 'https://api.polygon.io/v2/tickers/AAYYY'},
#  {'ticker': 'AAZZF',
#   'name': 'A2Z Smart Technologies Corp Common Stock',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000084481045',
#    'scfigi': 'BBG00JXQRF10',
#    'cfigi': 'BBG00TM0F0B2',
#    'figi': 'BBG00TM0F0S4'},
#   'url': 'https://api.polygon.io/v2/tickers/AAZZF'},
#  {'ticker': 'AB',
#   'name': 'AllianceBernstein Holding, L.P.',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'NYE',
#   'updated': '2020-06-23',
#   'codes': {'cik': '0000825313',
#    'figiuid': 'EQ0140918300001000',
#    'scfigi': 'BBG001S5N9S0',
#    'cfigi': 'BBG000B9WM03',
#    'figi': 'BBG000B9WPQ8'},
#   'url': 'https://api.polygon.io/v2/tickers/AB'},
#  {'ticker': 'ABAC',
#   'name': 'Agroback AD',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'RSD',
#   'active': False,
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000005568066',
#    'scfigi': 'BBG001SR7BL2',
#    'cfigi': 'BBG000PP66N1',
#    'figi': 'BBG000PP67B2'},
#   'url': 'https://api.polygon.io/v2/tickers/ABAC'},
#  {'ticker': 'ABAHF',
#   'name': 'Abacus Health Products Inc',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000071841480',
#    'scfigi': 'BBG002VKN6P0',
#    'cfigi': 'BBG00N7XBWL3',
#    'figi': 'BBG00N7XBX13'},
#   'url': 'https://api.polygon.io/v2/tickers/ABAHF'},
#  {'ticker': 'ABAKF',
#   'name': 'ABERDEEN ASIA-PACIFIC INCOME Ordinary Shares',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000000518058',
#    'scfigi': 'BBG001S72GW8',
#    'cfigi': 'BBG000MVJ470',
#    'figi': 'BBG000MVJ470'},
#   'url': 'https://api.polygon.io/v2/tickers/ABAKF'},
#  {'ticker': 'ABANF',
#   'name': 'Automatic Bank Services Ltd Ordinary Shares (Israel)',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'OTC',
#   'updated': '2020-04-21',
#   'url': 'https://api.polygon.io/v2/tickers/ABANF'},
#  {'ticker': 'ABASF',
#   'name': 'Aberdeen Asian Smaller Company Investment Trust',
#   'market': 'STOCKS',
#   'locale': 'US',
#   'currency': 'USD',
#   'active': True,
#   'primaryExch': 'GREY',
#   'updated': '2020-06-23',
#   'codes': {'figiuid': 'EQ0000000001190312',
#    'scfigi': 'BBG001S7WFZ4',
#    'cfigi': 'BBG000PRQ7T7',
#    'figi': 'BBG000PRQ7T7'},
#   'url': 'https://api.polygon.io/v2/tickers/ABASF'}]

# %%
# to fetch data from local files
energy_df = pd.read_csv("energy_tickers.csv", index_col=0, parse_dates=True)
finance_df = pd.read_csv("finance_tickers.csv", index_col=0, parse_dates=True)

energy_df.loc[:, "date"] = pd.to_datetime(energy_df["date"])
finance_df.loc[:, "date"] = pd.to_datetime(finance_df["date"])

# %% [markdown]
# ### Change to returns

# %%
# cpi that seasonally adjusted
cpi_sl_df = pd.read_csv("../CPIAUCSL.csv", parse_dates=True)
cpi_sl_df.columns = ["date", "cpi_all_urban_custormers_seasonally_adjusted"]
cpi_sl_df["date"] = pd.to_datetime(cpi_sl_df["date"])
cpi_sl_df[f"{cpi_sl_df.columns[1]}_pct_change"] = cpi_sl_df[cpi_sl_df.columns[1]].pct_change()

# cpi not seasonally adjusted
cpi_df = pd.read_csv("../CPIAUCNS.csv", parse_dates=True)
cpi_df.columns = ["date", "cpi_all_urban_customers"]
cpi_df["date"] = pd.to_datetime(cpi_df["date"])
cpi_df[f"{cpi_df.columns[1]}_pct_change"] = cpi_df[cpi_df.columns[1]].pct_change()

# historical fed interest rates
interest_rates_df = pd.read_excel("../fed-funds-rate-historical-chart.xlsx", sheet_name="Sheet1")
interest_rates_df.columns = ["date", "value"]
interest_rates_df["date"] = pd.to_datetime(interest_rates_df["date"])
interest_rates_df["value"] = interest_rates_df["value"].ffill()

# %%
# merge all this cpi stuff with the prices that you have
energy_df = pd.merge(
    energy_df.assign(grouper=energy_df["date"].dt.to_period("M")),
    cpi_df.assign(grouper=cpi_df["date"].dt.to_period("M")),
    how="outer", 
    on="grouper"
)

# %%
from scipy.signal import detrend

# %%
def get_returns_plot(
    df:pd.DataFrame, 
    tickers:list, 
    colors:list, 
    cpi_adj:str=None, 
    as_scatter:bool=False, 
    as_bars:bool=False, 
    as_line:bool=False
) -> go.Figure:
    
    fig = make_subplots(rows=3, cols=1, row_heights=[1, 2, 1], vertical_spacing=0.05)
    ys = []
    dfs = []
    suffixes = []
    closes = []
    cols = ["close_returns", "ticker", "cpi_all_urban_customers", "cpi_all_urban_customers_pct_change"]
    
    for ticker, color in zip(tickers, colors):
        dff = df[df["ticker"] == ticker].sort_values(by="date_x")
        dff = dff.rename(columns={"date_x": "date"})
        dff["date"] = dff["date"].dt.date
        dff = dff.set_index("date", drop=True, inplace=False)
        
        # store these variables for merging use
        suffixes.append(f"_{ticker}")
        closes.append(f"close_returns_{ticker}")

        if cpi_adj is None:
#             dff["close_returns"] = dff['close'].pct_change()# .cumsum().fillna(0.0)
            dff["close_returns"] = (( dff['close'].shift(-1) - dff["close"] ) / dff["close"]).cumsum().fillna(0.0)
        else:
            dff["close_returns"] = ((dff["close"].pct_change() + 1).astype(float) / (dff[f"{cpi_adj}_pct_change"] + 1.0) - 1 )#.cumsum().fillna(0.0)
            
        dff["close_returns"] = detrend(dff["close_returns"].ffill().fillna(0.0))
#         dff["close_returns"] = np.log(dff["close_returns"])
        dfs.append(dff)

        fig.append_trace(go.Histogram(x=dff["close_returns"], name=f"{ticker}_histogram", marker={"color": color}, legendgroup=ticker), row=1, col=1)
        fig.update_layout({"xaxis": {"side": "top"}, "height": 800, "width": 1800})

        if as_scatter:
            fig.add_scatter(x=dff.index, y=dff["close_returns"], row=2, col=1, name=ticker, legendgroup=ticker, mode="markers", marker={"color": color})
        elif as_bars:
            fig.add_bar(x=dff.index, y=dff["close_returns"], row=2, col=1, name=ticker, legendgroup=ticker, marker={"color": color})
        elif as_line:
            fig.add_scatter(x=dff.index, y=dff["close_returns"], row=2, col=1, name=ticker, legendgroup=ticker, marker={"color": color})
        else:
            fig.add_scatter(x=dff.index, y=dff["close_returns"], row=2, col=1, name=ticker, legendgroup=ticker, mode="markers", marker={"color": color})
        
        fig.update_layout({"xaxis": {"title": {"standoff": 1}}})
    
    # now merge these columns, and find out pearson corr
    merged_df = reduce(lambda x, y: pd.merge(left=x[cols], right=y[cols], left_index=True, right_index=True, suffixes=tuple(suffixes)), dfs)
    
    fig.add_scatter(
        x=merged_df.index, 
        y=merged_df[closes].fillna(0.0).rolling(7).corr(pairwise=True)[closes[1]], 
        row=3, 
        col=1,
        name=f"Corr b/w {tickers[0]} & {tickers[1]}"
    )
    
    return fig

energy_tickers = list(energy_df.ticker.unique())
ticker = energy_tickers[1]
cpi_col = cpi_df.columns[1]
colors = px.colors.sequential.Blackbody

get_returns_plot(
    df=energy_df,
    tickers=energy_tickers[2:4], 
    as_line=True,
    colors=[colors[0], colors[-1]],
#     cpi_adj=cpi_col, 
)
# Out:
# <div>                            <div id="c00b8dde-2824-406f-95df-180e77e621e8" class="plotly-graph-div" style="height:800px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c00b8dde-2824-406f-95df-180e77e621e8")) {                    Plotly.newPlot(                        "c00b8dde-2824-406f-95df-180e77e621e8",                        [{"legendgroup": "BLDP", "marker": {"color": "rgb(0,0,0)"}, "name": "BLDP_histogram", "type": "histogram", "x": [-0.03280345269093572, -0.04379641427094923, -0.10472753503330473, -0.11999052654309844, -0.159065620185423, -0.17681381453339018, -0.19264403710475664, -0.19812229280241717, -0.16175954431597725, -0.175269928527694, -0.1969425162091602, -0.16949896120723237, -0.15704893005230308, -0.16448413291239034, -0.17780552586495285, -0.18723635073257375, -0.17485746357309143, -0.15109595318888053, -0.09218026949260169, -0.06563005543937259, -0.0952462421715158, -0.08128986889391139, -0.02957575024148522, -0.0743982682342276, -0.05769222359059119, -0.06650937745185781, -0.10046334504231565, -0.15421746280894166, -0.13795658807181957, -0.11151995015245872, -0.12902569725905397, -0.12754743121758405, -0.13820703406550372, -0.12285195642983082, -0.09431660668531444, -0.06525538869876443, -0.08663189558879372, -0.027489795874499567, 0.017107820961982573, 0.06076251324120066, -0.049398938048746316, -0.013338732207945375, -0.05279040001786578, -0.03227477192347736, -0.01241770720385027, -0.0164424745294178, -0.02409779844188234, -0.06521241777590653, -0.06767408222168156, -0.10623504468625947, -0.08216431127038962, -0.11332232527620723, -0.1032967050048755, -0.1454161820765819, -0.1857597309596623, -0.1945220589069122, -0.1785835106507013, -0.16954563731610373, -0.1018919375288676, -0.12959241544875041, -0.1017373378130775, -0.12627717708845057, -0.11680774967699306, -0.09724918652340175, -0.08117571808313112, -0.08243456449809139, -0.11592402467754448, -0.11707951380459986, -0.09242864468160045, 0.016299227754443868, 0.01082097205678334, -0.018407283640877237, 0.03885453748604628, 0.015303992631759245, 0.015960706259251944, 0.05804342617134761, 0.10844409946088163, 0.18455349536189808, 0.2361598472075605, 0.25478959536718065, 0.2907426014397651, 0.37387194067881335, 0.2786926883034122, 0.1856231917298391, 0.07514493603217848, 0.15346556301608222, 0.09128627639058678, 0.21476976932680603, 0.17928183308703505, 0.16681754944526272, 0.15329909274257714, 0.21063745305302217, 0.21850524120664871, 0.21302698550898813, 0.23953367807097004, 0.21400072775161394, 0.2708480534493023, 0.23559746850470664, 0.2544874438539775, 0.23315015731931266, 0.24468174942827692, 0.3395556064066728, 0.4652773507090122, 0.3639716551245059, 0.38626031377960257, 0.22933609156748247, 0.22296097488327482, 0.16003209081936642, -0.042112831544960705, 0.007536357926317794, 0.12902439436348867, 0.1454803360736049, 0.17609964135155398, 0.1725046248252683, 0.08056020371407402, -0.05043245527576756, 0.11820693608539556, 0.011526275578115808, -0.12661641713180782, -0.07039801473178209, -0.12551307430353464, -0.11188304974641816, -0.20111130544407863, -0.18476145745824657, -0.1408405142239978, -0.1501355638147882, -0.09686541593645914, -0.10234367163411962, -0.11626583565506099, -0.1850044319853249, -0.2073658045661022, -0.2128440602637629, -0.21303830010937586, -0.2645086714443557, -0.20249381419435775, -0.229907553762986, -0.11929082265325863, -0.09521825092775138, -0.05247607034527413, -0.053573165035267656, -0.05905142073292813, 0.04125004003615074, -0.03128935964573065, 0.021371919540329576, 0.034874682823688, 0.018612113400537256, -0.019571791454705, 0.026179461044355867, 0.001208027958781277, -0.0012881203830145127, 0.011073068914369433, -0.0002474457901069371, 0.020718960608216874, -0.015293646234481817, -0.10148056334946509, -0.0534256284689 ...
